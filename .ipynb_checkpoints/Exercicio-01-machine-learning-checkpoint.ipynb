# %% [markdown]
# # Atividade 01
#
# #### 1 - Rode o mesmo programa nos dados contendo anos de escolaridade (primeira coluna) versus salário (segunda coluna). Baixe os dados no link: income.csvVisualizar o documento. Esse exemplo foi trabalhado em sala de aula.
#
# #### 2- Modifique o código original para imprimir o RSS a cada iteração do gradiente descendente.
#
#
# Depedências necessárias:

# %%
# !conda install --yes --prefix {sys.prefix} conda-forge altair vega_datasets notebook vega
# !conda install --yes --prefix {sys.prefix} conda-forge numpy
# Out:
# EnvironmentLocationNotFound: Not a conda environment: /home/hansolo/workspace/PythonNot/machine-learning-linear-regression/{sys.prefix}
#
#
# EnvironmentLocationNotFound: Not a conda environment: /home/hansolo/workspace/PythonNot/machine-learning-linear-regression/{sys.prefix}

# %%
from numpy import *


errors = list()
iterations = list()

def step_gradient(b_current, m_current, points, learning_rate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learning_rate * b_gradient)
    new_m = m_current - (learning_rate * m_gradient)
    return [new_b, new_m]
    
def compute_error_for_line_given_points(b, m, points):
    total_error = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        total_error += (y - (m * x + b)) **2
     
    return total_error / float(len(points))
        
    
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    
    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
        
        current_error = compute_error_for_line_given_points(b, m, points)
        print ("error =", current_error)
        errors.append(current_error)
        iterations.append(i+1)
    return [b, m]
    
def run():
    points = genfromtxt('data.csv', delimiter = ',') 
    #hyperparameters medida deve ser balanceado nem muito alto nem muito baixo para mais rapidamente convergir
    learning_rate = 0.0001
    #forma da inclinação da reta
    #y-intercept, m é a inclinação
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    print ("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
    print ("Running...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print("b:", b)
    print("m:", m)
    print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_line_given_points(b, m, points)))


if __name__ == "__main__":
    run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# error = 2648.2381266261386
# error = 2381.1735926230144
# error = 2142.151013653971
# error = 1928.2259499305476
# error = 1736.7631314659504
# error = 1565.4039948653665
# error = 1412.0376287932477
# error = 1274.7747702022896
# error = 1151.924530990372
# error = 1041.9735683871631
# error = 943.5674424757678
# error = 855.4939311975465
# error = 776.6680973019634
# error = 706.1189232850785
# error = 642.9773496759485
# error = 586.4655693176774
# error = 535.8874457621318
# error = 490.61993774500473
# error = 450.105424101551
# error = 413.8448345756185
# error = 381.3915019021827
# error = 352.34565942878487
# error = 326.34951649348716
# error = 303.0828508942081
# error = 282.2590641541991
# error = 263.6216509895024
# error = 246.94103948667004
# error = 232.01176306571264
# error = 218.6499293904183
# error = 206.69095504620364
# error = 195.9875380795778
# error = 186.40784342345904
# ...

# %% [markdown]
# #### 3 - O que acontece com o RSS ao longo das iterações (aumenta ou diminui) se você usar 1000 iterações? Plote o RSS vs número de iterações.
#
# Com base no observado nos prints acima é notável que o erro diminui no decorrer das iterações. Ao Chegar mais próximo a iteração 1000 esse valor vai diminuindo em menores proporções.

# %%
import altair as alt
import numpy as np
from vega_datasets import data
import pandas as pd

df = pd.DataFrame( {'iteration_number': iterations , 'RSS':  errors})
alt.Chart(df).mark_point().encode(
    x='iteration_number',
    y='RSS'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# #### 4 - Teste valores diferentes do número de iterações e learning_rate até que w0 e w1 sejam aproximadamente iguais a -39 e 5 respectivamente. Reporte os valores do número de iterações e learning_rate usados para atingir esses valores.

# %%
from numpy import *


def step_gradient(b_current, m_current, points, learning_rate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learning_rate * b_gradient)
    new_m = m_current - (learning_rate * m_gradient)
    return [new_b, new_m]
    
def compute_error_for_line_given_points(b, m, points):
    total_error = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        total_error += (y - (m * x + b)) **2
     
    return total_error / float(len(points))
        
    
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    
    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
        
        current_error = compute_error_for_line_given_points(b, m, points)
    return [b, m]
    
def run():
    points = genfromtxt('data.csv', delimiter = ',') 
    #hyperparameters medida deve ser balanceado nem muito alto nem muito baixo para mais rapidamente convergir
    learning_rate = 0.0020
    #forma da inclinação da reta
    #y-intercept, m é a inclinação
    initial_b = 0
    initial_m = 0
    num_iterations = 12000
    print ("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
    print ("Running...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print("b:", b)
    print("m:", m)
    print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_line_given_points(b, m, points)))


if __name__ == "__main__":
    run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# b: -35.40291854891965
# m: 5.358791214244222
# After 12000 iterations b = -35.40291854891965, m = 5.358791214244222, error = 30.608990022656617

# %% [markdown]
# Para atingir os valores sugeridos, foi utilizado: número de iterações = 12000 e learning_rate = 0.0020

# %% [markdown]
# #### 5 - O algoritmo do vídeo usa o número de iterações como critério de parada. Mude o algoritmo para considerar um critério de parada que é relacionado ao tamanho do gradiente (como no algoritmo apresentado em sala). Plote o tamanho do gradiente vs número de iterações.

# %%
from numpy import *
import math
import sys

num_gradient = list()
num_iterations_list = list()

def step_gradient(b_current, m_current, points, learning_rate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learning_rate * b_gradient)
    new_m = m_current - (learning_rate * m_gradient)
    gradient_length = math.sqrt((b_gradient**2) + (m_gradient**2))
    return [new_b, new_m, gradient_length]
    
def compute_error_for_line_given_points(b, m, points):
    total_error = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        total_error += (y - (m * x + b)) **2
     
    return total_error / float(len(points))
        
    
def gradient_descent_runner(points, starting_b, starting_m, learning_rate):
    b = starting_b
    m = starting_m
    i = 0    
    while True:
        b, m, gradient_length = step_gradient(b, m, array(points), learning_rate)

        num_gradient.append(gradient_length)
        num_iterations_list.append(i+1)

        if i > 0 and num_gradient[i-1] - gradient_length < 0.0001:
            break
        i += 1

    return [b, m]
    
def run():
    points = genfromtxt('data.csv', delimiter = ',') 
    #hyperparameters medida deve ser balanceado nem muito alto nem muito baixo para mais rapidamente convergir
    learning_rate = 0.0001
    #forma da inclinação da reta
    #y-intercept, m é a inclinação
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    print ("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
    print ("Running...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate)
    print("b:", b)
    print("m:", m)

if __name__ == "__main__":
    run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# b: 0.12279674864680933
# m: 3.243910413787385

# %%
import altair as alt
import numpy as np
from vega_datasets import data
import pandas as pd

df = pd.DataFrame( {'iteration_number': num_iterations_list , 'gradient_number':  num_gradient})
alt.Chart(df).mark_point().encode(
    x='iteration_number',
    y='gradient_number'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# #### 6 - Ache um valor de tolerância que se aproxime dos valores dos parâmetros do item 4 acima. Que valor foi esse?

# %%
from numpy import *
import math

num_gradient = list()
num_iterations_list = list()

def step_gradient(b_current, m_current, points, learning_rate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learning_rate * b_gradient)
    new_m = m_current - (learning_rate * m_gradient)
    gradient_length = math.sqrt((b_gradient**2) + (m_gradient**2))
    return [new_b, new_m, gradient_length]
    
def compute_error_for_line_given_points(b, m, points):
    total_error = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        total_error += (y - (m * x + b)) **2
     
    return total_error / float(len(points))
        
    
def gradient_descent_runner(points, starting_b, starting_m, learning_rate):
    b = starting_b
    m = starting_m
    i = 0    
    while True:
        b, m, gradient_length = step_gradient(b, m, array(points), learning_rate)

        num_gradient.append(gradient_length)
        num_iterations_list.append(i+1)

        if i > 0 and num_gradient[i-1] - gradient_length < 0.000011:
            break
        i += 1

    return [b, m]

def run():
    points = genfromtxt('data.csv', delimiter = ',') 
    #hyperparameters medida deve ser balanceado nem muito alto nem muito baixo para mais rapidamente convergir
    learning_rate = 0.003
    #forma da inclinação da reta
    #y-intercept, m é a inclinação
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    print ("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
    print ("Running...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate)
    print("b:", b)
    print("m:", m)

if __name__ == "__main__":
    run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# b: -39.041834777014344
# m: 5.575408464370292

# %% [markdown]
# Para atingir os valores sugeridos, foi utilizado: tamanho de gradientes = 0.000011 = 12000 e learning_rate = 0.003

# %% [markdown]
# #### 7 - Implemente a forma fechada (equações normais) de calcular os coeficientes de regressão (vide algoritmo nos slides). Compare o tempo de processamento com o gradiente descendente considerando sua solução do item 6.

# %%
import datetime

data_inicial = None
data_final = None

def equacao_normal(file):
    points = genfromtxt(file, delimiter=",")
    points = array(points)

    x = 0
    y = 0
    for element in points:
        x += element[0]
        y += element[1]
    
    x_mean = x/float(len(points))
    y_mean = y/float(len(points))
    
    vx = 0
    vx2 = 0
    for element in points:
        vx += (element[0] - x_mean) * (element[1] - y_mean)
        vx2 += (element[0] - x_mean) ** 2
        
    w1 = vx/vx2
    w0 = y_mean - w1 * x_mean
    
    return [w0, w1]

from numpy import *
import math

num_gradient = list()
num_iterations_list = list()

def step_gradient(b_current, m_current, points, learning_rate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learning_rate * b_gradient)
    new_m = m_current - (learning_rate * m_gradient)
    gradient_length = math.sqrt((b_gradient**2) + (m_gradient**2))
    return [new_b, new_m, gradient_length]
    
def compute_error_for_line_given_points(b, m, points):
    total_error = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        total_error += (y - (m * x + b)) **2
     
    return total_error / float(len(points))
        
    
def gradient_descent_runner(points, starting_b, starting_m, learning_rate):
    b = starting_b
    m = starting_m
    i = 0    
    while True:
        b, m, gradient_length = step_gradient(b, m, array(points), learning_rate)

        num_gradient.append(gradient_length)
        num_iterations_list.append(i+1)

        if i > 0 and num_gradient[i-1] - gradient_length < 0.000011:
            break
        i += 1

    return [b, m]

def run():
    points = genfromtxt('data.csv', delimiter = ',') 
    #hyperparameters medida deve ser balanceado nem muito alto nem muito baixo para mais rapidamente convergir
    learning_rate = 0.003
    #forma da inclinação da reta
    #y-intercept, m é a inclinação
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    print ("Running...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate)
    print("b:", b)
    print("m:", m)

if __name__ == "__main__":
    data_inicial = datetime.datetime.now()
    run()
    data_final = datetime.datetime.now()
    dif = (tempo_eq_normal_fim - tempo_eq_normal_inicio).total_seconds()
    print ("tempo aprox. execução gradient descent questão 6: ", str(dif) + "s")
    print ("=====================================================================")


tempo_eq_normal_inicio = datetime.datetime.now()
[w0, w1] = equacao_normal("data.csv")
tempo_eq_normal_fim = datetime.datetime.now()

dif = (tempo_eq_normal_fim - tempo_eq_normal_inicio).total_seconds()

print ("tempo aprox. execução forma fechada: ", str(dif) + "s")
print("w0: ",w0, ",w1: ", w1)
# Out:
# Running...
# b: -39.041834777014344
# m: 5.575408464370292
# tempo aprox. execução gradient descent questão 6:  0.000797s
# ...
# tempo aprox. execução forma fechada:  0.00123s
# w0:  -39.44625667909617 ,w1:  5.599482874119919

# %% [markdown]
# De acordo com os resultado o algoritmo utilizado na questão 6 é mais lento na execução.
